# %% [markdown]
# # object_detection_yolo.ipynb
#
# Project notebook (skeleton). Sections:
#
# - Setup
# - Data preview
# - Data conversion
# - Training (YOLOv8)
# - Evaluation (mAP / PR)
# - Inference demo
# - Results
#
# (Implement cells here.)

# %% [markdown]
# ---
#
# Notebook created as a skeleton: add runnable code cells for each section.
